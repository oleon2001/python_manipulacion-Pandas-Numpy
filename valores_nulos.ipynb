# %% [markdown]
# ### Importar librerías

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Crear diccionario y DataFrame

# %%
dict = {'Col1':[1,2,3,np.nan],
 'Col2':[4,np.nan,6,7],
 'Col3':['a','b','c',None]}
dict
# Out:
# {'Col1': [1, 2, 3, nan], 'Col2': [4, nan, 6, 7], 'Col3': ['a', 'b', 'c', None]}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %% [markdown]
# ### Ver valores nulos

# %%
df.isnull() # evalua si hay valores que son nulos tanto strings como numeros
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %%
df.isnull()*1 # a los valores nulos les realizas operaciones
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %% [markdown]
# ### Llenar valores nulos

# %%
df.fillna('Missing') #se le asigna un valor si encuentra un valor nulo
# Out:
#       Col1     Col2     Col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
df
# Out:
#    Col1      Col2  Col3
# 0   1.0  4.000000     a
# 1   2.0  5.666667     b
# 2   3.0  6.000000     c
# 3   2.0  7.000000  None

# %%
non_numeric_cols = df.select_dtypes(exclude=['number']).columns
df[non_numeric_cols] = df[non_numeric_cols].fillna('')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 numeric_cols = df.select_dtypes(exclude=['number']).columns
# ...

# %% [markdown]
# ### Interpolar

# %%
df.interpolate()
# Out:
# /tmp/ipykernel_25588/4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %% [markdown]
# ### Borrar valores nulos

# %%
df.dropna()
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c
