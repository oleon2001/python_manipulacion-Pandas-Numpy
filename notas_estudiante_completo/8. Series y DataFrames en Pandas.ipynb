# %%
import pandas as pd

# %%
psg = pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'], index = [1,7,10,30])
psg
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict = {'Jugador':['Navas','Mbappe','Neymar','Messi'],
    'Altura':[183.0, 170.0, 170.0, 163.0],
    'Goles':[2, 200, 150, 500]}
df_psg =pd.DataFrame(dict, index=[1,7,10,30])
df_psg
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    150
# 30   Messi   163.0    500

# %%
df_psg.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %% [markdown]
# ## Reto

# %%
dict = {'Jugador':['Luis Suarez','Jorge Molina', 'Antonio Puertas', 'German Sanchez', 'Luis Milla', 'Lui­s Manuel Arantes Maximiano'],
'Posicion':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],
'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],
'Goles':[7, 7, 5, 2, 2, 0]}

pd.DataFrame(dict,index = [9, 23, 10, 6, 5, 1])
# Out:
#                            Jugador        Posicion  Altura  Goles
# 9                      Luis Suarez       Delantero   185.0      7
# 23                    Jorge Molina       Delantero   187.0      7
# 10                 Antonio Puertas  Centrocampista   185.0      5
# 6                   German Sanchez         Defensa   187.0      2
# 5                       Luis Milla  Centrocampista   175.0      2
# 1   Lui­s Manuel Arantes Maximiano         Portero   190.0      0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=88a0fc44-9153-47d8-9fa2-e6788d3ddf7b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
