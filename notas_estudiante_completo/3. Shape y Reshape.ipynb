# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,3))

# %%
arr.shape
# Out:
# (3, 3)

# %%
arr
# Out:
# array([[6, 7, 2],
#        [8, 7, 8],
#        [9, 2, 1]])

# %%
arr.reshape(1,9)
# Out:
# array([[6, 7, 2, 8, 7, 8, 9, 2, 1]])

# %%
arr.reshape(9,1)
# Out:
# array([[6],
#        [7],
#        [2],
#        [8],
#        [7],
#        [8],
#        [9],
#        [2],
#        [1]])

# %%
np.random.randint(1,100,(3,4,3))
# Out:
# array([[[57, 63, 18],
#         [44, 61, 83],
#         [37, 40,  5],
#         [85, 95, 36]],
#
#        [[53, 60, 17],
#         [37, 73, 92],
#         [60, 49, 43],
#         [57, 39, 23]],
#
#        [[18, 70, 82],
#         [63, 54, 77],
#         [47, 14, 99],
#         [60,  7, 20]]])

# %%
tensorOri = np.random.randint(1,100,(3,4,3))

# %%
tensorOri.shape
# Out:
# (3, 4, 3)

# %%
tensorOri.reshape(3,1,12)
# Out:
# array([[[81, 67, 58, 60, 21, 62,  5, 77, 74, 21, 45, 80]],
#
#        [[51, 63, 73, 71, 15, 25, 17, 17, 71, 65, 58, 71]],
#
#        [[10, 19, 42, 30, 73, 38, 75,  1, 56, 40, 56, 32]]])

# %%
tensorRe = tensorOri.reshape(3,1,12)

# %%
tensorRe.reshape(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e537fc5af362> in <module>
# ----> 1 tensorRe.reshape(1,2,3)
#
# ValueError: cannot reshape array of size 36 into shape (1,2,3)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=88a0fc44-9153-47d8-9fa2-e6788d3ddf7b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
