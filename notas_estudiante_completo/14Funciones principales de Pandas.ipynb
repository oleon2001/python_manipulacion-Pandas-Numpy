# %%
import pandas as pd

# %%
dfDriver = pd.read_csv('/work/DataFrames/F1 Drivers 2022.csv', sep= ';')
dfTeam = pd.read_csv('/work/DataFrames/F1 Schedule 2022.csv', sep = ';')
dfBooks = pd.read_csv('/work/DataFrames/bestsellers-with-categories.csv')
dfDriver
# Out:
#               Driver Nationality  Age          Team  Driver Points  \
# 0    Valtteri Bottas         FIN   33    Alfa Romeo             24
# 1        Zhou Guanyu         CHN   23    Alfa Romeo              1
# 2       Pierre Gasly         FRA   26    AlphaTauri              6
# 3       Yuki Tsunoda         JPN   22    AlphaTauri             10
# 4    Fernando Alonso         ESP   41        Alpine              2
# 5       Estaban Ocon         FRA   26        Alpine             20
# 6   Sebastian Vettel         GER   35  Aston Martin              4
# 7       Lance Stroll         CAN   24  Aston Martin              1
# 8    Nico�Hulkenberg         GER   35  Aston Martin              0
# 9    Charles Leclerc         MON   25       Ferrari             86
# 10      Carlos Sainz         ESP   28       Ferrari             38
# 11   Mick Schumacher         GER   23          Haas              0
# 12   Kevin Magnussen         DNK   30          Haas             15
# ...

# %%
dfDriver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Driver                21 non-null     object
#  1   Nationality           21 non-null     object
#  2   Age                   21 non-null     int64
#  3   Team                  21 non-null     object
#  4   Driver Points         21 non-null     int64
#  5   Team Points           21 non-null     int64
#  6   Bahrain - SG          20 non-null     float64
#  7   Bahrain - RR          20 non-null     object
#  8   Saudia Arabia - SG    19 non-null     float64
#  9   Saudia Arabia - RR    19 non-null     object
#  10  Australia - SG        20 non-null     float64
#  11  Australia - RR        20 non-null     object
#  12  Italy - SG            20 non-null     object
#  13  Italy - RR            20 non-null     object
#  14  United States - SG    0 non-null      float64
# ...

# %%
dfBooks['Author'].value_counts()
# Out:
# Jeff Kinney                           12
# Rick Riordan                          11
# Gary Chapman                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# George W. Bush                         1
# Golden Books                           1
# John Heilemann                         1
# Bruce Springsteen                      1
# Mark Owen                              1
# Name: Author, Length: 248, dtype: int64

# %%
dfDriver.describe()
# Out:
#              Age  Driver Points  Team Points  Bahrain - SG  \
# count  21.000000      21.000000    21.000000      20.00000
# mean   28.476190      21.142857    42.523810      10.50000
# std     5.418663      24.228673    43.395413       5.91608
# min    22.000000       0.000000     1.000000       1.00000
# 25%    24.000000       1.000000    15.000000       5.75000
# 50%    26.000000      11.000000    22.000000      10.50000
# 75%    33.000000      35.000000    77.000000      15.25000
# max    41.000000      86.000000   124.000000      20.00000
#
#        Saudia Arabia - SG  Australia - SG  United States - SG  \
# count           19.000000        20.00000                 0.0
# mean            10.000000        10.50000                 NaN
# std              5.627314         5.91608                 NaN
# min              1.000000         1.00000                 NaN
# 25%              5.500000         5.75000                 NaN
# ...

# %%
dfTeam.set_index('Round', inplace= True)

# %%
dfTeam
# Out:
#                                             Circuit       Location  \
# Round
# 1                     Bahrain International Circuit        Bahrain
# 2                           Jeddah Corniche Circuit  Saudia Arabia
# 3                               Albert Park Circuit      Australia
# 4      Autodromo Internazionale Enzo e Dino Ferrari          Italy
# 5                     Miami International Autodrome  United States
# 6                    Circuit de Barcelona-Catalunya          Spain
# 7                                 Circuit de Monaco         Monaco
# 8                                 Baku City Circuit     Azerbaijan
# 9                         Circuit Gilles Villeneuve         Canada
# 10                              Silverstone Circuit  Great Britain
# 11                                    Red Bull Ring        Austria
# 12                              Circuit Paul Ricard         France
# 13                                      Hungaroring        Hungary
# ...

# %%
dfTeam.sort_values('2021 Pole Position')
# Out:
#                                             Circuit       Location  \
# Round
# 7                                 Circuit de Monaco         Monaco
# 8                                 Baku City Circuit     Azerbaijan
# 17                        Marina Bay Street Circuit      Singapore
# 2                           Jeddah Corniche Circuit  Saudia Arabia
# 3                               Albert Park Circuit      Australia
# 4      Autodromo Internazionale Enzo e Dino Ferrari          Italy
# 6                    Circuit de Barcelona-Catalunya          Spain
# 13                                      Hungaroring        Hungary
# 1                     Bahrain International Circuit        Bahrain
# 19                          Circuit of the Americas  United States
# 16                     Autodromo Nazionale di Monza          Italy
# 15                                Circuit Zandvoort    Netherlands
# 14                     Circuit de Spa-Francorchamps        Belgium
# ...

# %%
dfTeam.drop(['2022 Pole Position','2022 Winner', '2022 Second Place', '2022 Third Place', '2022 Fastest Lap (driver - time)'], axis = 1, inplace = True)

# %%
dfTeam.head(2)
# Out:
#                              Circuit       Location        Date  \
# Round
# 1      Bahrain International Circuit        Bahrain  2022-03-20
# 2            Jeddah Corniche Circuit  Saudia Arabia  2022-03-27
#
#        Circuit Length (km)  Laps  Race Length (km) Most Wins (driver - times)  \
# Round
# 1                    5.412    57           308.238         Lewis Hamilton - 5
# 2                    6.174    50           308.450         Lewis Hamilton - 1
#
#       2021 Pole Position     2021 Winner 2021 Second Place 2021 Third Place  \
# Round
# 1         Max Verstappen  Lewis Hamilton    Max Verstappen  Valtteri Bottas
# 2         Lewis Hamilton  Lewis Hamilton    Max Verstappen  Valtteri Bottas
#
#       2021 Fastest Lap (driver - time)
# Round
# 1           Valtteri Bottas - 1:32.090
# 2            Lewis Hamilton - 1:30.734

# %%
dfTeam['2021 Winner'].value_counts()
# Out:
# Max Verstappen      9
# Lewis Hamilton      6
# Valtteri Bottas     2
# None                1
# Daniel Ricciardo    1
# Sergio Perez        1
# Sebastian Vettel    1
# Esteban Ocon        1
# Name: 2021 Winner, dtype: int64

# %%
dfTeam.drop_duplicates()
# Out:
#                                             Circuit       Location  \
# Round
# 1                     Bahrain International Circuit        Bahrain
# 2                           Jeddah Corniche Circuit  Saudia Arabia
# 3                               Albert Park Circuit      Australia
# 4      Autodromo Internazionale Enzo e Dino Ferrari          Italy
# 5                     Miami International Autodrome  United States
# 6                    Circuit de Barcelona-Catalunya          Spain
# 7                                 Circuit de Monaco         Monaco
# 8                                 Baku City Circuit     Azerbaijan
# 9                         Circuit Gilles Villeneuve         Canada
# 10                              Silverstone Circuit  Great Britain
# 11                                    Red Bull Ring        Austria
# 12                              Circuit Paul Ricard         France
# 13                                      Hungaroring        Hungary
# ...

# %%
dfTeam.sort_values('Date', ascending=False).head()
# Out:
#                             Circuit       Location        Date  \
# Round
# 22               Yas Marina Circuit      Abu Dhabi  2022-11-20
# 21       Aut�dromo Jos� Carlos Pace         Brazil  2022-11-13
# 20     Aut�dromo Hermanos Rodr�guez         Mexico  2022-10-30
# 19          Circuit of the Americas  United States  2022-10-23
# 18                   Suzuka Circuit          Japan  2022-10-09
#
#        Circuit Length (km)  Laps  Race Length (km) Most Wins (driver - times)  \
# Round
# 22                   5.281    58           306.183         Lewis Hamilton - 5
# 21                   4.309    71           305.879            Alain Prost - 6
# 20                   4.304    71           305.354         Max Verstappen - 3
# 19                   5.513    56           308.405         Lewis Hamilton - 6
# 18                   5.807    53           307.471     Michael Schumacher - 6
#
#       2021 Pole Position      2021 Winner 2021 Second Place 2021 Third Place  \
# Round
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=88a0fc44-9153-47d8-9fa2-e6788d3ddf7b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
